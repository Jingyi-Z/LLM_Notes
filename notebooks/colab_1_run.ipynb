# %%
# LOAD THE .PY FILE TO BE RUN USING COLAB GPU
# !git clone https://github.com/Jingyi-Z/LLM_Notes.git
# %cd LLM_Notes

# Install dependencies in Colab
# !pip install -U pip
# !pip install -r requirements.txt

# RUN script in Colab
# !python colab_1.py

# Mount Drive for large artifacts (/artifacts)
from google.colab import drive
drive.mount('/content/drive')
# Example: save heavy outputs to Drive path (not git)
# /content/drive/MyDrive/LLM_Notes_artifacts/

# Commit only small outputs to git (/results)
# !git config user.name "Jingyi-Z"
# !git config user.email "50727655+Jingyi-Z@users.noreply.github.com"
# !git add results/ colab_1.py notebooks/ # adjust paths as needed
# !git commit -m "Add experiment outputs"
# !git push
# Out:
# d:\Pi_sync\Research\LLM\LLM_Notes
# Cloning into 'LLM_Notes'...
