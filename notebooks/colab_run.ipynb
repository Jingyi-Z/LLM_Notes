# %% [markdown]
# <a href="https://colab.research.google.com/github/Jingyi-Z/LLM_Notes/blob/main/notebooks/colab_run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LOAD THE .PY FILE TO BE RUN USING COLAB GPU
# %cd /content
# !rm -rf LLM_Notes
# !git clone https://github.com/Jingyi-Z/LLM_Notes.git
# %cd LLM_Notes

# Install dependencies in Colab
# !pip install -U pip
# !pip install -r ./src/requirements.txt

# Store Huggingface token in Secrets
from google.colab import userdata
from huggingface_hub import login
# Huggingface login
login(token = userdata.get('HF_read'))

# Mount Drive for large artifacts (/artifacts)
from google.colab import drive
drive.mount('/content/drive')
# Example: save heavy outputs to Drive path (not git)
# /content/drive/MyDrive/LLM_Notes_artifacts/
# Out:
# /content
# Cloning into 'LLM_Notes'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 44 (delta 21), reused 23 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 11.80 KiB | 11.80 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# /content/LLM_Notes
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
model_id = "meta-llama/Llama-3.2-3B-Instruct" # Change to your desired model
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)
print("Tokenizer and model loaded successfully!")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading weights:   0%|          | 0/254 [00:00<?, ?it/s]
# Tokenizer and model loaded successfully!

# %%
# RUN script in Colab
# !python ./src/colab_1.py
# Out:
# Loading weights: 100% 254/254 [00:00<00:00, 862.42it/s, Materializing param=model.norm.weight]
# Tokenizer and model loaded successfully!
# Vocabulary size of the tokenizer:  128000
# Token ID 100000 corresponds to token: 'IClient'
# Token IDs [100000, 100001, 100002] correspond to tokens: 'IClientISODEIssuer'
# Text: 'Hello, how are you?' is encoded to token IDs: [9906, 11, 1268, 527, 499, 30]

# %%
# Commit only small outputs to git (/results)

gh_token = userdata.get("GITHUB_TOKEN")
# !git config --global user.name "Jingyi-Z"
# !git config --global user.email "50727655+Jingyi-Z@users.noreply.github.com"

# !git status
# !git add -A
# !git add results/ notebooks/ # adjust paths as needed
# !git status
# !git commit -m "Add notebooks and experiment outputs from Colab"

# Push with authenticated URL
# !git remote set-url origin https://Jingyi-Z:$gh_token@github.com/Jingyi-Z/LLM_Notes.git
# !git push origin main

# Reset remote back to clean URL
# !git remote set-url origin https://github.com/Jingyi-Z/LLM_Notes.git
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
